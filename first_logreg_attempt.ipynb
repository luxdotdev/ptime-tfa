# %%
import collect_data

dat = collect_data.df

dat.head(30)
# Out:
#    attacker_team attacker_hero victim_team victim_hero  attacker_team_won  \
# 0         Team 2           Mei      Team 1    Symmetra               True
# 1         Team 1      Baptiste      Team 1    Baptiste              False
# 2         Team 2           Mei      Team 1         Mei               True
# 3         Team 2      Ramattra      Team 1    Ramattra               True
# 4         Team 2       Sojourn      Team 1         Mei               True
# 5         Team 1       Sojourn      Team 2     Sojourn              False
# 6         Team 2       Sojourn      Team 1    Symmetra               True
# 7         Team 1       Sojourn      Team 2    Ramattra               True
# 8         Team 1      Symmetra      Team 2       Lúcio               True
# 9         Team 2       Sojourn      Team 1       Lúcio               True
# 10        Team 2       Junkrat      Team 1    Baptiste               True
# 11        Team 2       Junkrat      Team 1         Mei              False
# ...
